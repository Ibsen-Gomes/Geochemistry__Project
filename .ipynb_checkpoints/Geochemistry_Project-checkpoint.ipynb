# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sweetviz as sv

from pyrolite.util.classification import TAS
from pyrolite.util.synthetic import normal_frame, random_cov_matrix

# %% [markdown]
# ### Loading Geochemical data:

# %%
df = pd.read_excel('aula5.xlsx')
df
# Out:
#    Sample   SiO2   TiO2  Al2O3  Fe2O3    MnO   MgO   CaO  Na2O   K2O  ...  \
# 0      S1  71.82  0.447  14.26   2.24  0.020  0.44  1.35  2.91  5.93  ...
# 1      S2  70.01  0.702  14.37   3.47  0.044  0.67  1.43  2.96  5.14  ...
# 2      S3  69.59  0.656  14.06   3.44  0.060  0.66  1.73  2.79  5.29  ...
# 3      S4  68.12  0.750  13.87   3.63  0.053  0.68  1.82  2.54  5.89  ...
# 4      S5  72.63  0.347  13.90   1.71  0.023  0.33  0.91  2.95  5.80  ...
# 5      S6  73.53  0.346  14.26   1.71  0.022  0.34  0.99  2.99  5.79  ...
# 6      S7  71.73  0.458  13.77   2.46  0.031  0.52  1.46  2.75  5.36  ...
# 7      S8  72.83  0.410  13.54   2.11  0.025  0.42  0.99  2.54  6.15  ...
# 8      S9  73.84  0.382  13.45   1.71  0.017  0.34  1.16  2.76  5.57  ...
# 9     S10  67.60  0.744  13.86   3.55  0.047  0.68  1.86  2.56  5.88  ...
# 10    S11  68.21  0.898  14.61   3.69  0.045  0.80  1.98  2.91  5.08  ...
# 11    S12  70.55  0.498  13.85   2.62  0.038  0.49  1.43  3.08  4.81  ...
# ...

# %% [markdown]
# ### Separation and calculation of new percentages:

# %%
def new_perc(df, l):
    '''
    input:
    df = dataframe original
    l = linha que deseja realizar a operação
    
    operation:
    
    output:
    df_n.T = um sub dataframe com novas porcentagens de cada elemento
    '''
    
    df_sub = df.iloc[l,1:11]
    df_new = np.copy(df_sub)
    df_total = df.iloc[l,12]
    s = 0

    for i in range(len(df_sub)):
        s += df_sub.iloc[i]

        for j in range(len(df_sub)):
            df_new[j] = (df_sub[j]*100)/s

    df_n = [df_new[0], df_new[1], df_new[2], df_new[3], df_new[4], df_new[5], 
            df_new[6], df_new[7], df_new[8], df_new[9]]
    
    df_n = np.array(df_n).T
    
    return df_n

# %%
def new_dataframe(df):
    '''
    input = df (data frame original)
    
    operation = use the function "new_por" to calculate a new % to all rows
    
    return = new data frame with new %
    '''
    
    df_new = []
    for k in range(len(df)):
        df_new.append(new_perc(df,k))

    cab = ['SiO2', 'TiO2', 'Al2O3', 'Fe2O3', 'MnO', 'MgO', 'CaO', 'Na2O', 'K2O', 'P2O5']
    df_new = pd.DataFrame(df_new, columns = cab)
    
    return df_new

# %%
df = new_dataframe(df)

# %%
df
# Out:
#          SiO2      TiO2      Al2O3     Fe2O3       MnO       MgO       CaO  \
# 0   72.154073  0.449079  14.326331  2.250419  0.020093  0.442047  1.356280
# 1   70.712886  0.709048  14.514272  3.504838  0.044442  0.676727  1.444357
# 2   70.659789  0.666085  14.276141  3.492882  0.060922  0.670146  1.756595
# 3   69.821551  0.768734  14.216455  3.720673  0.054324  0.696986  1.865461
# 4   73.534474  0.351321  14.073099  1.731295  0.023286  0.334110  0.921332
# 5   73.421336  0.345489  14.238926  1.707473  0.021967  0.339498  0.988537
# 6   72.646067  0.463849  13.945857  2.491417  0.031396  0.526641  1.478646
# 7   73.435846  0.413411  13.652634  2.127552  0.025208  0.423494  0.998235
# 8   74.353785  0.384658  13.543586  1.721898  0.017118  0.342366  1.168071
# 9   69.690003  0.767002  14.288512  3.659756  0.048453  0.701024  1.917506
# 10  69.260685  0.911832  14.835048  3.746840  0.045693  0.812323  2.010499
# ...

# %% [markdown]
# ### Crossplots:

# %%
### Mas qual a correlação??? Existe uma forma melhor para visualizar???

# %% [markdown]
# ### Correlation Matrix:

# %%
mask_sana = np.triu(df.corr())

# %%
corr_sana = sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cmap='coolwarm') #, mask=mask_sana)
corr_sana.figure.set_size_inches(10, 8)

# %%
### Interpretação desse gráfico???

# %% [markdown]
# ### Machine learning:

# %% [markdown]
# ##### K-Means:

# %% [markdown]
# #### Self-Organizing Maps:

# %% [markdown]
# ### END

# %% [markdown]
# ### Código lixo:

# %%
def new_por(df, l):
    '''
    input:
    df = dataframe original
    l = linha que deseja realizar a operação
    
    operação:
    
    output:
    df_n.T = um sub dataframe com novas porcentagens de cada elemento
    '''
    
    df_sub = df.iloc[l,1:11]
    df_new = np.copy(df_sub)
    df_total = df.iloc[l,12]
    s = 0

    for i in range(len(df_sub)):
        s += df_sub.iloc[i]

        for j in range(len(df_sub)):
            df_new[j] = df_sub[j]*df_total/s

    df_n =  pd.DataFrame({'Elemento': ['SiO2', 'TiO2', 'Al2O3', 'Fe2O3', 'MnO', 
                           'MgO', 'CaO', 'Na2O', 'K2O', 'P2O5'],
                          'velha %': [df_sub[0], df_sub[1], df_sub[2],
                                 df_sub[3], df_sub[4], df_sub[5], 
                                 df_sub[6], df_sub[7], df_sub[8],
                                 df_sub[9]],
                          'nova %':[df_new[0], df_new[1], df_new[2],
                                 df_new[3], df_new[4], df_new[5], 
                                 df_new[6], df_new[7], df_new[8],
                                 df_new[9]]
                         })
    
    return df_n.T

# %%
df_sub = df.iloc[15,1:11]
pd.DataFrame(df_sub).T

# %%
df_total = df.iloc[1,12]
df_total

# %%
df_sub['SiO2']

# %%
df[SiO2	TiO2	Al2O3	Fe2O3	MnO	MgO	CaO	Na2O	K2O'Total']

# %%
df_total = df.iloc[0,12]
df_total

# %%
df_sub[0]+df_sub[1]+df_sub[2]

# %%
df_sub.iloc[1]

# %%
s = 0
for i in range(len(df_sub)):
    s += df_sub.iloc[i]

# %%
s

# %%
df_n =  pd.DataFrame({'nova %':[df_new[0], df_new[1], df_new[2],
                             df_new[3], df_new[4], df_new[5], 
                             df_new[6], df_new[7], df_new[8],
                             df_new[9]],
                     'velha %': [df_sub[0], df_sub[1], df_sub[2],
                             df_sub[3], df_sub[4], df_sub[5], 
                             df_sub[6], df_sub[7], df_sub[8],
                             df_sub[9]]})
df_n

# %%
for r in range(3):
    dfe = pd.DataFrame({'X':[1, 2, 3, 4, 5],
                       'Y':[r]})

# %%
#pd.concat([pd.DataFrame(df_sub).T, pd.DataFrame(df_new).T], ignore_index = True)

# %%
df_test = ['SiO2', 'TiO2', 'Al2O3', 'Fe2O3', 'MnO', 'MgO', 'CaO', 'Na2O', 'K2O', 'P2O5']})

df_cab

# %%
df_cab.append(pd.DataFrame(df_new))

# %%
pd.DataFrame(df_sub).T

# %%
pd.merge(df_cab, df_new, how="right")

#df = df.eval('Sum = X + Y')

# %%
SiO2 = 71.82*100.38699/99.536999
SiO2
